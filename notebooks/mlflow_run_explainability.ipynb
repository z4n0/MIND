# %%
import os, pathlib
repo_root = pathlib.Path.cwd()
if repo_root.name == "notebooks":
    repo_root = repo_root.parent
os.environ["MLFLOW_TRACKING_URI"] = f"file://{repo_root / 'mlruns'}"
print(os.environ["MLFLOW_TRACKING_URI"])
TRACKING_URI = os.environ["MLFLOW_TRACKING_URI"]
# Out:
# file:///home/zano/Documents/TESI/FOLDER_CINECA/mlruns

# %%
import os
from pathlib import Path
from mlflow.tracking import MlflowClient
from mlflow.entities import ViewType

client = MlflowClient(tracking_uri=TRACKING_URI)

def list_experiments(prefixes=None):
    exps = client.search_experiments(view_type=ViewType.ACTIVE_ONLY)
    if prefixes:
        prefixes = tuple(prefixes)
        exps = [e for e in exps if e.name.startswith(prefixes)]
    for e in exps:
        print(f"id={e.experiment_id} | name={e.name} | artifact={e.artifact_location}")

list_experiments(prefixes=["DS1", "DS2"])  # change/omit prefixes to see all active
# Out:
# id=870194084958402490 | name=DS2_3c_MSA_vs_PD_supervised | artifact=file:///home/zano/Documents/TESI/FOLDER_CINECA/mlruns/870194084958402490
# id=914421233606463568 | name=DS2_4c_MSA_vs_PD_supervised | artifact=file:///home/zano/Documents/TESI/FOLDER_CINECA/mlruns/914421233606463568
# id=161682510127360652 | name=DS2_4c_MSA-P_vs_PD_supervised | artifact=file:///home/zano/Documents/TESI/FOLDER_CINECA/mlruns/161682510127360652
# id=120358550691752282 | name=DS2_3c_MSA-P_vs_PD_supervised | artifact=file:///home/zano/Documents/TESI/FOLDER_CINECA/mlruns/120358550691752282
# id=248261519201116701 | name=DS2_pretrained_MSA-P_vs_PD_supervised | artifact=file:///home/zano/Documents/TESI/FOLDER_CINECA/mlruns/248261519201116701
# id=160785092358134542 | name=DS2_pretrained_MSA_vs_PD_supervised | artifact=file:///home/zano/Documents/TESI/FOLDER_CINECA/mlruns/160785092358134542
# id=836292825509124052 | name=DS1_pretrained_MSA_vs_PD_supervised | artifact=file:///home/zano/Documents/TESI/FOLDER_CINECA/mlruns/836292825509124052
# id=527746675993109141 | name=DS1_3c_MSA_vs_PD_supervised | artifact=file:///home/zano/Documents/TESI/FOLDER_CINECA/mlruns/527746675993109141
# id=169604731846263291 | name=DS1_pretrained_4C_MSA-P_vs_PD_supervised | artifact=file:///home/zano/Documents/TESI/FOLDER_CINECA/mlruns/169604731846263291
# id=825458163127476619 | name=DS1_pretrained_MSA-P_vs_PD_supervised | artifact=file:///home/zano/Documents/TESI/FOLDER_CINECA/mlruns/825458163127476619
# id=281933238953629554 | name=DS1_4c_MSA_vs_PD_supervised | artifact=file:///home/zano/Documents/TESI/FOLDER_CINECA/mlruns/281933238953629554
# id=963165936264272572 | name=DS1_4c_MSA-P_vs_PD_supervised | artifact=file:///home/zano/Documents/TESI/FOLDER_CINECA/mlruns/963165936264272572
# id=788257751769076553 | name=DS1_3c_MSA-P_vs_PD_supervised | artifact=file:///home/zano/Documents/TESI/FOLDER_CINECA/mlruns/788257751769076553

# %%
import mlflow

EXPERIMENT_NAME = "DS2_4c_MSA_vs_PD_supervised"

mlflow.set_tracking_uri(TRACKING_URI)
exp = mlflow.get_experiment_by_name(EXPERIMENT_NAME)
if exp is None:
    raise ValueError(f"Experiment '{EXPERIMENT_NAME}' not found at {TRACKING_URI}")

print(f"Experiment '{EXPERIMENT_NAME}' (id={exp.experiment_id}) runs:")
runs_df = mlflow.search_runs(experiment_ids=[exp.experiment_id])
for _, row in runs_df.iterrows():
    run_id = row["run_id"]
    run_name = row.get("tags.mlflow.runName", "Unnamed")
    status = row.get("status", "UNKNOWN")
    print(f"  run_id: {run_id} | name: {run_name} | status: {status}")
# Out:
# Experiment 'DS2_4c_MSA_vs_PD_supervised' (id=914421233606463568) runs:
#   run_id: cb888978ceb64b05a1a26cfa19115082 | name: ViT_monai_11-03_at:00-06-52 | status: FINISHED
#   run_id: ba62da81a2454bf59253f24d37cc6dda | name: Resnet18_oversamp_monai_11-02_at:22-34-52 | status: FINISHED
#   run_id: ccae05cc6a3c4b5ea17255e3de2af932 | name: Densenet169_oversamp_monai_11-02_at:19-13-37 | status: FINISHED
#   run_id: 2c2e7113057d45859a0c881f3861f2e5 | name: Densenet121_oversamp_monai_11-02_at:15-43-52 | status: FINISHED

# %% [markdown]
# # MLflow run → train predictions + explanations
#
# Loads a trained model from a chosen MLflow run, rebuilds the training set with the stored config, runs predictions over the full set, and saves GradCAMs (CNNs) or attention rollouts (ViT).

# %%
import os
import sys
from pathlib import Path
import mlflow
import torch

# --- REQUIRED: set the MLflow run you want to load ---
RUN_ID = "2c2e7113057d45859a0c881f3861f2e5"

# If you want to force CPU set USE_GPU = False
USE_GPU = torch.cuda.is_available()

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

ARTIFACT_DIR = PROJECT_ROOT / "notebooks" / "models" / RUN_ID
OUTPUT_DIR = PROJECT_ROOT / "notebooks" / "images" / f"{RUN_ID}_explanations"
DATA_ROOT = Path(os.environ.get("DATA_ROOT", PROJECT_ROOT / "data"))

device = torch.device("cuda" if USE_GPU and torch.cuda.is_available() else "cpu")

mlflow.set_tracking_uri(TRACKING_URI)
ARTIFACT_DIR.mkdir(parents=True, exist_ok=True)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

print(f"Tracking URI: {mlflow.get_tracking_uri()}")
print(f"Project root: {PROJECT_ROOT}")
print(f"Artifact cache: {ARTIFACT_DIR}")
print(f"Output dir: {OUTPUT_DIR}")
print(f"Data root: {DATA_ROOT}")
print(f"Using device: {device}")
# Out:
# Tracking URI: file:///home/zano/Documents/TESI/FOLDER_CINECA/mlruns
# Project root: /home/zano/Documents/TESI/FOLDER_CINECA
# Artifact cache: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/models/2c2e7113057d45859a0c881f3861f2e5
# Output dir: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations
# Data root: /home/zano/Documents/TESI/FOLDER_CINECA/data
# Using device: cuda

# %%
from pathlib import Path
import mlflow
from configs.ConfigLoader import ConfigLoader
import utils.transformations_functions as tf
import pickle 

run = mlflow.get_run(RUN_ID)
print(
    f"Run name: {run.data.tags.get('mlflow.runName', 'n/a')} | Experiment: {run.info.experiment_id}"
)

# Download config artifacts from mlflow logged run and rebuild the original config
config_dir = Path(
    mlflow.artifacts.download_artifacts(
        run_id=RUN_ID, artifact_path="config", dst_path=ARTIFACT_DIR
    )
)

#exclude base.yaml if other configs are present
config_files = [p for p in config_dir.glob("*.yaml") if p.name != "base.yaml"]
print(f"Config files found: {[p.name for p in config_files]}")
# if not config_files:
#     config_files = list(config_dir.glob("*.yaml"))
if not config_files:
    raise FileNotFoundError(f"No YAML config found in {config_dir}")

cfg_path = config_files[0]
cfg = ConfigLoader(str(cfg_path))

class_names = cfg.get_class_names()
num_channels = cfg.get_model_input_channels()
print(f"Loaded config {cfg_path.name} | classes: {class_names} | channels: {num_channels}")

# Load the trained model from MLflow
model_uri = f"runs:/{RUN_ID}/model"
model = mlflow.pytorch.load_model(
    model_uri,
    map_location=device,
    pickle_module=pickle,  # avoid cloudpickle.Unpickler issue
)
model.to(device).eval()
print("Model loaded and set to eval().")

# Use the validation/test transform path (no heavy train-time augmentations)
_, test_transforms,_ = tf.get_transforms(cfg)


################################ààààà
from monai.transforms import Compose

transforms_list = (
    test_transforms.transforms 
    if isinstance(test_transforms, Compose) 
    else test_transforms
)
for t in transforms_list:
    print(f"Test transform: {t}")
# Out:
# Run name: Densenet121_oversamp_monai_11-02_at:15-43-52 | Experiment: 914421233606463568
# Downloading artifacts:   0%|          | 0/2 [00:00<?, ?it/s]
# 2025/12/02 17:16:46 WARNING mlflow.pytorch: Attempting to load the PyTorch model with a pickle module, 'pickle', that does not match the pickle module that was used to save the model: 'cloudpickle'.
# Config files found: ['densenet121.yaml']
# Configuration loaded from /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/models/2c2e7113057d45859a0c881f3861f2e5/config/base.yaml
# Configuration: {'dataset': {'class_names': ['MSA', 'PD']}, 'data_splitting': {'random_seed': 42, 'val_set_size': 0.15, 'test_set_size': 0.1, 'num_folds': 8, 'lr_discovery_folds': 4}, 'data_augmentation': {'resize_spatial_size': [512, 512], 'rand_flip_prob': 0.3, 'rand_flip_spatial_axes': [0, 1], 'rand_rotate90_prob': 0.3, 'rand_rotate90_max_k': 3, 'rand_gaussian_noise_prob': 0.5, 'rand_gaussian_noise_mean': 0.0, 'rand_gaussian_noise_std': 0.1, 'crop_size': [256, 256], 'intensity_augmentation_preset': 'light', 'use_crop': False, 'crop_percentage': 0.95}, 'data_loading': {'batch_size': 32, 'num_workers': 4}, 'model': {'model_name': 'base', 'spatial_dims': 2, 'in_channels': 4, 'out_channels': 2, 'dropout_prob': 0.1, 'patch_size': [16, 16], 'library': 'torchvision'}, 'training': {'num_epochs': 210, 'early_stopping_patience': 35, 'mixup_alpha': 0, 'oversample': True, 'undersample': False, 'weighted_loss': False, 'transfer_learning': False, 'freezed_layerIndex': None, 'lr_discovery_method': 'nested'}, 'optimizer': {'learning_rate': '1e-4', 'optimizer_name': 'AdamW', 'weight_decay': '2e-5', 'patience': 25}, 'scheduler': {'scheduler_name': 'ReduceLROnPlateau', 'factor': 0.5, 'scheduler_patience': 10, 'threshold': '1e-4', 'min_lr': '1e-8'}}
# Configuration loaded from /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/models/2c2e7113057d45859a0c881f3861f2e5/config/densenet121.yaml
# Configuration: {'dataset': {'class_names': ['MSA', 'PD']}, 'class_names': None, 'ablation': None, 'data_splitting': {'random_seed': 42, 'val_set_size': 0.15, 'test_set_size': 0.1, 'num_folds': 8, 'lr_discovery_folds': 4}, 'data_augmentation': {'resize_spatial_size': [512, 512], 'rand_flip_prob': 0.3, 'rand_flip_spatial_axes': [0, 1], 'rand_rotate90_prob': 0.3, 'rand_rotate90_max_k': 3, 'rand_gaussian_noise_prob': 0.5, 'rand_gaussian_noise_mean': 0.0, 'rand_gaussian_noise_std': 0.1, 'crop_size': [256, 256], 'intensity_augmentation_preset': 'light', 'use_crop': False, 'crop_percentage': 0.95}, 'data_loading': {'batch_size': 32, 'num_workers': 4}, 'model': {'model_name': 'Densenet121', 'spatial_dims': 2, 'in_channels': 4, 'out_channels': 2, 'dropout_prob': 0.1, 'patch_size': [16, 16], 'library': 'monai'}, 'training': {'num_epochs': 210, 'early_stopping_patience': 35, 'mixup_alpha': 0, 'oversample': True, 'undersample': False, 'weighted_loss': False, 'transfer_learning': False, 'freezed_layerIndex': None, 'lr_discovery_method': 'nested', 'pretrained': False}, 'optimizer': {'learning_rate': '2e-4', 'optimizer_name': 'AdamW', 'weight_decay': '1e-4', 'patience': 25}, 'scheduler': {'scheduler_name': 'ReduceLROnPlateau', 'factor': 0.5, 'scheduler_patience': 10, 'threshold': '1e-4', 'min_lr': '1e-8'}, 'num_epochs': None, 'freeze_layers': None, 'pretrained_weights': None, 'crop_size': None, 'use_color_transforms': None, 'lr_discovery_folds': None, 'mixup_alpha': None, 'oversample': None, 'undersample': None, 'weighted_loss': None, 'transfer_learning': None, 'freezed_layer_index': None, 'use_crop': None, 'crop_percentage': None}
# Loaded config densenet121.yaml | classes: ['MSA', 'PD'] | channels: 4
# Model loaded and set to eval().
# Model Densenet121 supported by torchvision: True and pretrained: False
# Using pretrained model: False
# intensity_augmentation_preset is light
# Using pretrained model: False and supported by torchvision: True with color transforms: True
# the model is not supported by torchvision or is not pretrained
# Model Densenet121 not supported using custom transforms
# intensity_augmentation_preset is light
# NO FOLD SPECIFIC STATS provided, using default x channel normalization
# NO FOLD SPECIFIC STATS provided, using default x channel normalization
# Test transform: <classes.CustomTiffFileReader.CustomTiffFileReader object at 0x7b49258448c0>
# Test transform: <monai.transforms.utility.dictionary.EnsureTyped object at 0x7b49258453a0>
# Test transform: <monai.transforms.utility.dictionary.EnsureTyped object at 0x7b49258461e0>
# Test transform: <monai.transforms.utility.dictionary.Lambdad object at 0x7b49258458e0>
# Test transform: <monai.transforms.spatial.dictionary.Resized object at 0x7b4925844d40>
# Test transform: <monai.transforms.intensity.dictionary.ScaleIntensityd object at 0x7b4925844050>
# Test transform: <monai.transforms.intensity.dictionary.NormalizeIntensityd object at 0x7b49258444a0>

# %%
import numpy as np
from utils.train_functions import make_loader

data_subdir = "3c_MIP" if num_channels == 3 else "4c_MIP"
data_dir = DATA_ROOT / data_subdir
if not data_dir.exists():
    raise FileNotFoundError(f"{data_dir} not found; point DATA_ROOT to the dataset root")

image_paths, labels = [], []
for idx, cname in enumerate(class_names):
    class_dir = data_dir / cname
    tif_paths = sorted(class_dir.glob("*.tif"))
    filtered = [p for p in tif_paths if "vaso" not in p.name.lower()]
    image_paths.extend(str(p) for p in filtered)
    labels.extend([idx] * len(filtered))
    print(f"{cname}: {len(filtered)} files from {class_dir}")

train_images_np = np.array(image_paths)
train_labels_np = np.array(labels)
print(f"Total images: {len(train_images_np)}")

train_loader = make_loader(
    train_images_np,
    train_labels_np,
    transforms=test_transforms,
    cfg=cfg,
    shuffle=False,
)
# Out:
# MSA: 104 files from /home/zano/Documents/TESI/FOLDER_CINECA/data/4c_MIP/MSA
# PD: 60 files from /home/zano/Documents/TESI/FOLDER_CINECA/data/4c_MIP/PD
# Total images: 164

# %%
import torch
from utils.test_functions import calculate_classification_metrics

def predict_dataset(model, loader, class_names, device):
    model.eval()
    preds, labels, probs = [], [], []
    with torch.no_grad():
        for batch in loader:
            imgs = batch["image"].to(device)
            y = batch["label"].to(device).long()

            outputs = model(imgs)
            logits = outputs[0] if isinstance(outputs, (tuple, list)) else outputs
            batch_probs = torch.softmax(logits, dim=1)

            preds.append(batch_probs.argmax(dim=1).cpu())
            labels.append(y.cpu())
            probs.append(batch_probs.cpu())

    preds_np = torch.cat(preds).numpy()
    labels_np = torch.cat(labels).numpy()
    probs_np = torch.cat(probs).numpy()
    metrics = calculate_classification_metrics(
        labels_np, preds_np, probs=probs_np, class_names=class_names
    )
    return {
        "predictions": preds_np,
        "true_labels": labels_np,
        "probs": probs_np,
        "metrics": metrics,
    }

train_results = predict_dataset(model, train_loader, class_names, device)
train_results["metrics"]
# Out:
# {'accuracy': 0.49390243902439024,
#  'precision': 0.24444444444444444,
#  'recall': 0.18333333333333332,
#  'f1': 0.20952380952380953,
#  'balanced_accuracy': np.float64(0.42820512820512824),
#  'confusion_matrix': array([[70, 34],
#         [49, 11]]),
#  'mcc': np.float64(-0.15500152720937346),
#  'auc': np.float64(0.3918269230769231),
#  'classification_report': {'MSA': {'precision': 0.5882352941176471,
#    'recall': 0.6730769230769231,
#    'f1-score': 0.6278026905829597,
#    'support': 104.0},
#   'PD': {'precision': 0.24444444444444444,
#    'recall': 0.18333333333333332,
#    'f1-score': 0.20952380952380953,
#    'support': 60.0},
#   'accuracy': 0.49390243902439024,
#   'macro avg': {'precision': 0.41633986928104577,
#    'recall': 0.42820512820512824,
#    'f1-score': 0.4186632500533846,
#    'support': 164.0},
#   'weighted avg': {'precision': 0.46245815399330464,
#    'recall': 0.49390243902439024,
#    'f1-score': 0.4747738316588804,
#    'support': 164.0}}}

# %%
import importlib
import utils.vit_explanation_functions as vit_expl
from utils import explainability_functions as explainability_functions

vit_expl = importlib.reload(vit_expl)
explainability_functions = importlib.reload(explainability_functions)

# %%
print(class_names)
# Out:
# ['MSA-P', 'PD']

# %%
print("Model Architecture (Truncated view of layers):")
for name, module in model.named_modules():
    # Filter to show only Conv2d layers or specific blocks to avoid clutter
    if isinstance(module, torch.nn.Conv2d) or "block" in name:
        print(f"{name}")
# Out:
# Model Architecture (Truncated view of layers):
# features.conv0
# features.denseblock1
# features.denseblock1.denselayer1
# features.denseblock1.denselayer1.layers
# features.denseblock1.denselayer1.layers.norm1
# features.denseblock1.denselayer1.layers.relu1
# features.denseblock1.denselayer1.layers.conv1
# features.denseblock1.denselayer1.layers.norm2
# features.denseblock1.denselayer1.layers.relu2
# features.denseblock1.denselayer1.layers.conv2
# features.denseblock1.denselayer2
# features.denseblock1.denselayer2.layers
# features.denseblock1.denselayer2.layers.norm1
# features.denseblock1.denselayer2.layers.relu1
# features.denseblock1.denselayer2.layers.conv1
# features.denseblock1.denselayer2.layers.norm2
# features.denseblock1.denselayer2.layers.relu2
# features.denseblock1.denselayer2.layers.conv2
# features.denseblock1.denselayer3
# features.denseblock1.denselayer3.layers
# features.denseblock1.denselayer3.layers.norm1
# features.denseblock1.denselayer3.layers.relu1
# features.denseblock1.denselayer3.layers.conv1
# features.denseblock1.denselayer3.layers.norm2
# features.denseblock1.denselayer3.layers.relu2
# features.denseblock1.denselayer3.layers.conv2
# features.denseblock1.denselayer4
# features.denseblock1.denselayer4.layers
# features.denseblock1.denselayer4.layers.norm1
# features.denseblock1.denselayer4.layers.relu1
# features.denseblock1.denselayer4.layers.conv1
# features.denseblock1.denselayer4.layers.norm2
# features.denseblock1.denselayer4.layers.relu2
# features.denseblock1.denselayer4.layers.conv2
# features.denseblock1.denselayer5
# features.denseblock1.denselayer5.layers
# features.denseblock1.denselayer5.layers.norm1
# features.denseblock1.denselayer5.layers.relu1
# features.denseblock1.denselayer5.layers.conv1
# features.denseblock1.denselayer5.layers.norm2
# features.denseblock1.denselayer5.layers.relu2
# features.denseblock1.denselayer5.layers.conv2
# features.denseblock1.denselayer6
# features.denseblock1.denselayer6.layers
# features.denseblock1.denselayer6.layers.norm1
# features.denseblock1.denselayer6.layers.relu1
# features.denseblock1.denselayer6.layers.conv1
# features.denseblock1.denselayer6.layers.norm2
# features.denseblock1.denselayer6.layers.relu2
# features.denseblock1.denselayer6.layers.conv2
# features.transition1.conv
# features.denseblock2
# features.denseblock2.denselayer1
# features.denseblock2.denselayer1.layers
# features.denseblock2.denselayer1.layers.norm1
# features.denseblock2.denselayer1.layers.relu1
# features.denseblock2.denselayer1.layers.conv1
# features.denseblock2.denselayer1.layers.norm2
# features.denseblock2.denselayer1.layers.relu2
# features.denseblock2.denselayer1.layers.conv2
# features.denseblock2.denselayer2
# features.denseblock2.denselayer2.layers
# features.denseblock2.denselayer2.layers.norm1
# features.denseblock2.denselayer2.layers.relu1
# features.denseblock2.denselayer2.layers.conv1
# features.denseblock2.denselayer2.layers.norm2
# features.denseblock2.denselayer2.layers.relu2
# features.denseblock2.denselayer2.layers.conv2
# features.denseblock2.denselayer3
# features.denseblock2.denselayer3.layers
# features.denseblock2.denselayer3.layers.norm1
# features.denseblock2.denselayer3.layers.relu1
# features.denseblock2.denselayer3.layers.conv1
# features.denseblock2.denselayer3.layers.norm2
# features.denseblock2.denselayer3.layers.relu2
# features.denseblock2.denselayer3.layers.conv2
# features.denseblock2.denselayer4
# features.denseblock2.denselayer4.layers
# features.denseblock2.denselayer4.layers.norm1
# features.denseblock2.denselayer4.layers.relu1
# features.denseblock2.denselayer4.layers.conv1
# features.denseblock2.denselayer4.layers.norm2
# features.denseblock2.denselayer4.layers.relu2
# features.denseblock2.denselayer4.layers.conv2
# features.denseblock2.denselayer5
# features.denseblock2.denselayer5.layers
# features.denseblock2.denselayer5.layers.norm1
# features.denseblock2.denselayer5.layers.relu1
# features.denseblock2.denselayer5.layers.conv1
# features.denseblock2.denselayer5.layers.norm2
# features.denseblock2.denselayer5.layers.relu2
# features.denseblock2.denselayer5.layers.conv2
# features.denseblock2.denselayer6
# features.denseblock2.denselayer6.layers
# features.denseblock2.denselayer6.layers.norm1
# features.denseblock2.denselayer6.layers.relu1
# features.denseblock2.denselayer6.layers.conv1
# features.denseblock2.denselayer6.layers.norm2
# features.denseblock2.denselayer6.layers.relu2
# features.denseblock2.denselayer6.layers.conv2
# features.denseblock2.denselayer7
# features.denseblock2.denselayer7.layers
# features.denseblock2.denselayer7.layers.norm1
# features.denseblock2.denselayer7.layers.relu1
# features.denseblock2.denselayer7.layers.conv1
# features.denseblock2.denselayer7.layers.norm2
# features.denseblock2.denselayer7.layers.relu2
# features.denseblock2.denselayer7.layers.conv2
# features.denseblock2.denselayer8
# features.denseblock2.denselayer8.layers
# features.denseblock2.denselayer8.layers.norm1
# features.denseblock2.denselayer8.layers.relu1
# features.denseblock2.denselayer8.layers.conv1
# features.denseblock2.denselayer8.layers.norm2
# features.denseblock2.denselayer8.layers.relu2
# features.denseblock2.denselayer8.layers.conv2
# features.denseblock2.denselayer9
# features.denseblock2.denselayer9.layers
# features.denseblock2.denselayer9.layers.norm1
# features.denseblock2.denselayer9.layers.relu1
# features.denseblock2.denselayer9.layers.conv1
# features.denseblock2.denselayer9.layers.norm2
# features.denseblock2.denselayer9.layers.relu2
# features.denseblock2.denselayer9.layers.conv2
# features.denseblock2.denselayer10
# features.denseblock2.denselayer10.layers
# features.denseblock2.denselayer10.layers.norm1
# features.denseblock2.denselayer10.layers.relu1
# features.denseblock2.denselayer10.layers.conv1
# features.denseblock2.denselayer10.layers.norm2
# features.denseblock2.denselayer10.layers.relu2
# features.denseblock2.denselayer10.layers.conv2
# features.denseblock2.denselayer11
# features.denseblock2.denselayer11.layers
# features.denseblock2.denselayer11.layers.norm1
# features.denseblock2.denselayer11.layers.relu1
# features.denseblock2.denselayer11.layers.conv1
# features.denseblock2.denselayer11.layers.norm2
# features.denseblock2.denselayer11.layers.relu2
# features.denseblock2.denselayer11.layers.conv2
# features.denseblock2.denselayer12
# features.denseblock2.denselayer12.layers
# features.denseblock2.denselayer12.layers.norm1
# features.denseblock2.denselayer12.layers.relu1
# features.denseblock2.denselayer12.layers.conv1
# features.denseblock2.denselayer12.layers.norm2
# features.denseblock2.denselayer12.layers.relu2
# features.denseblock2.denselayer12.layers.conv2
# features.transition2.conv
# features.denseblock3
# features.denseblock3.denselayer1
# features.denseblock3.denselayer1.layers
# features.denseblock3.denselayer1.layers.norm1
# features.denseblock3.denselayer1.layers.relu1
# features.denseblock3.denselayer1.layers.conv1
# features.denseblock3.denselayer1.layers.norm2
# features.denseblock3.denselayer1.layers.relu2
# features.denseblock3.denselayer1.layers.conv2
# features.denseblock3.denselayer2
# features.denseblock3.denselayer2.layers
# features.denseblock3.denselayer2.layers.norm1
# features.denseblock3.denselayer2.layers.relu1
# features.denseblock3.denselayer2.layers.conv1
# features.denseblock3.denselayer2.layers.norm2
# features.denseblock3.denselayer2.layers.relu2
# features.denseblock3.denselayer2.layers.conv2
# features.denseblock3.denselayer3
# features.denseblock3.denselayer3.layers
# features.denseblock3.denselayer3.layers.norm1
# features.denseblock3.denselayer3.layers.relu1
# features.denseblock3.denselayer3.layers.conv1
# features.denseblock3.denselayer3.layers.norm2
# features.denseblock3.denselayer3.layers.relu2
# features.denseblock3.denselayer3.layers.conv2
# features.denseblock3.denselayer4
# features.denseblock3.denselayer4.layers
# features.denseblock3.denselayer4.layers.norm1
# features.denseblock3.denselayer4.layers.relu1
# features.denseblock3.denselayer4.layers.conv1
# features.denseblock3.denselayer4.layers.norm2
# features.denseblock3.denselayer4.layers.relu2
# features.denseblock3.denselayer4.layers.conv2
# features.denseblock3.denselayer5
# features.denseblock3.denselayer5.layers
# features.denseblock3.denselayer5.layers.norm1
# features.denseblock3.denselayer5.layers.relu1
# features.denseblock3.denselayer5.layers.conv1
# features.denseblock3.denselayer5.layers.norm2
# features.denseblock3.denselayer5.layers.relu2
# features.denseblock3.denselayer5.layers.conv2
# features.denseblock3.denselayer6
# features.denseblock3.denselayer6.layers
# features.denseblock3.denselayer6.layers.norm1
# features.denseblock3.denselayer6.layers.relu1
# features.denseblock3.denselayer6.layers.conv1
# features.denseblock3.denselayer6.layers.norm2
# features.denseblock3.denselayer6.layers.relu2
# features.denseblock3.denselayer6.layers.conv2
# features.denseblock3.denselayer7
# features.denseblock3.denselayer7.layers
# features.denseblock3.denselayer7.layers.norm1
# features.denseblock3.denselayer7.layers.relu1
# features.denseblock3.denselayer7.layers.conv1
# features.denseblock3.denselayer7.layers.norm2
# features.denseblock3.denselayer7.layers.relu2
# features.denseblock3.denselayer7.layers.conv2
# features.denseblock3.denselayer8
# features.denseblock3.denselayer8.layers
# features.denseblock3.denselayer8.layers.norm1
# features.denseblock3.denselayer8.layers.relu1
# features.denseblock3.denselayer8.layers.conv1
# features.denseblock3.denselayer8.layers.norm2
# features.denseblock3.denselayer8.layers.relu2
# features.denseblock3.denselayer8.layers.conv2
# features.denseblock3.denselayer9
# features.denseblock3.denselayer9.layers
# features.denseblock3.denselayer9.layers.norm1
# features.denseblock3.denselayer9.layers.relu1
# features.denseblock3.denselayer9.layers.conv1
# features.denseblock3.denselayer9.layers.norm2
# features.denseblock3.denselayer9.layers.relu2
# features.denseblock3.denselayer9.layers.conv2
# features.denseblock3.denselayer10
# features.denseblock3.denselayer10.layers
# features.denseblock3.denselayer10.layers.norm1
# features.denseblock3.denselayer10.layers.relu1
# features.denseblock3.denselayer10.layers.conv1
# features.denseblock3.denselayer10.layers.norm2
# features.denseblock3.denselayer10.layers.relu2
# features.denseblock3.denselayer10.layers.conv2
# features.denseblock3.denselayer11
# features.denseblock3.denselayer11.layers
# features.denseblock3.denselayer11.layers.norm1
# features.denseblock3.denselayer11.layers.relu1
# features.denseblock3.denselayer11.layers.conv1
# features.denseblock3.denselayer11.layers.norm2
# features.denseblock3.denselayer11.layers.relu2
# features.denseblock3.denselayer11.layers.conv2
# features.denseblock3.denselayer12
# features.denseblock3.denselayer12.layers
# features.denseblock3.denselayer12.layers.norm1
# features.denseblock3.denselayer12.layers.relu1
# features.denseblock3.denselayer12.layers.conv1
# features.denseblock3.denselayer12.layers.norm2
# features.denseblock3.denselayer12.layers.relu2
# features.denseblock3.denselayer12.layers.conv2
# features.denseblock3.denselayer13
# features.denseblock3.denselayer13.layers
# features.denseblock3.denselayer13.layers.norm1
# features.denseblock3.denselayer13.layers.relu1
# features.denseblock3.denselayer13.layers.conv1
# features.denseblock3.denselayer13.layers.norm2
# features.denseblock3.denselayer13.layers.relu2
# features.denseblock3.denselayer13.layers.conv2
# features.denseblock3.denselayer14
# features.denseblock3.denselayer14.layers
# features.denseblock3.denselayer14.layers.norm1
# features.denseblock3.denselayer14.layers.relu1
# features.denseblock3.denselayer14.layers.conv1
# features.denseblock3.denselayer14.layers.norm2
# features.denseblock3.denselayer14.layers.relu2
# features.denseblock3.denselayer14.layers.conv2
# features.denseblock3.denselayer15
# features.denseblock3.denselayer15.layers
# features.denseblock3.denselayer15.layers.norm1
# features.denseblock3.denselayer15.layers.relu1
# features.denseblock3.denselayer15.layers.conv1
# features.denseblock3.denselayer15.layers.norm2
# features.denseblock3.denselayer15.layers.relu2
# features.denseblock3.denselayer15.layers.conv2
# features.denseblock3.denselayer16
# features.denseblock3.denselayer16.layers
# features.denseblock3.denselayer16.layers.norm1
# features.denseblock3.denselayer16.layers.relu1
# features.denseblock3.denselayer16.layers.conv1
# features.denseblock3.denselayer16.layers.norm2
# features.denseblock3.denselayer16.layers.relu2
# features.denseblock3.denselayer16.layers.conv2
# features.denseblock3.denselayer17
# features.denseblock3.denselayer17.layers
# features.denseblock3.denselayer17.layers.norm1
# features.denseblock3.denselayer17.layers.relu1
# features.denseblock3.denselayer17.layers.conv1
# features.denseblock3.denselayer17.layers.norm2
# features.denseblock3.denselayer17.layers.relu2
# features.denseblock3.denselayer17.layers.conv2
# features.denseblock3.denselayer18
# features.denseblock3.denselayer18.layers
# features.denseblock3.denselayer18.layers.norm1
# features.denseblock3.denselayer18.layers.relu1
# features.denseblock3.denselayer18.layers.conv1
# features.denseblock3.denselayer18.layers.norm2
# features.denseblock3.denselayer18.layers.relu2
# features.denseblock3.denselayer18.layers.conv2
# features.denseblock3.denselayer19
# features.denseblock3.denselayer19.layers
# features.denseblock3.denselayer19.layers.norm1
# features.denseblock3.denselayer19.layers.relu1
# features.denseblock3.denselayer19.layers.conv1
# features.denseblock3.denselayer19.layers.norm2
# features.denseblock3.denselayer19.layers.relu2
# features.denseblock3.denselayer19.layers.conv2
# features.denseblock3.denselayer20
# features.denseblock3.denselayer20.layers
# features.denseblock3.denselayer20.layers.norm1
# features.denseblock3.denselayer20.layers.relu1
# features.denseblock3.denselayer20.layers.conv1
# features.denseblock3.denselayer20.layers.norm2
# features.denseblock3.denselayer20.layers.relu2
# features.denseblock3.denselayer20.layers.conv2
# features.denseblock3.denselayer21
# features.denseblock3.denselayer21.layers
# features.denseblock3.denselayer21.layers.norm1
# features.denseblock3.denselayer21.layers.relu1
# features.denseblock3.denselayer21.layers.conv1
# features.denseblock3.denselayer21.layers.norm2
# features.denseblock3.denselayer21.layers.relu2
# features.denseblock3.denselayer21.layers.conv2
# features.denseblock3.denselayer22
# features.denseblock3.denselayer22.layers
# features.denseblock3.denselayer22.layers.norm1
# features.denseblock3.denselayer22.layers.relu1
# features.denseblock3.denselayer22.layers.conv1
# features.denseblock3.denselayer22.layers.norm2
# features.denseblock3.denselayer22.layers.relu2
# features.denseblock3.denselayer22.layers.conv2
# features.denseblock3.denselayer23
# features.denseblock3.denselayer23.layers
# features.denseblock3.denselayer23.layers.norm1
# features.denseblock3.denselayer23.layers.relu1
# features.denseblock3.denselayer23.layers.conv1
# features.denseblock3.denselayer23.layers.norm2
# features.denseblock3.denselayer23.layers.relu2
# features.denseblock3.denselayer23.layers.conv2
# features.denseblock3.denselayer24
# features.denseblock3.denselayer24.layers
# features.denseblock3.denselayer24.layers.norm1
# features.denseblock3.denselayer24.layers.relu1
# features.denseblock3.denselayer24.layers.conv1
# features.denseblock3.denselayer24.layers.norm2
# features.denseblock3.denselayer24.layers.relu2
# features.denseblock3.denselayer24.layers.conv2
# features.transition3.conv
# features.denseblock4
# features.denseblock4.denselayer1
# features.denseblock4.denselayer1.layers
# features.denseblock4.denselayer1.layers.norm1
# features.denseblock4.denselayer1.layers.relu1
# features.denseblock4.denselayer1.layers.conv1
# features.denseblock4.denselayer1.layers.norm2
# features.denseblock4.denselayer1.layers.relu2
# features.denseblock4.denselayer1.layers.conv2
# features.denseblock4.denselayer2
# features.denseblock4.denselayer2.layers
# features.denseblock4.denselayer2.layers.norm1
# features.denseblock4.denselayer2.layers.relu1
# features.denseblock4.denselayer2.layers.conv1
# features.denseblock4.denselayer2.layers.norm2
# features.denseblock4.denselayer2.layers.relu2
# features.denseblock4.denselayer2.layers.conv2
# features.denseblock4.denselayer3
# features.denseblock4.denselayer3.layers
# features.denseblock4.denselayer3.layers.norm1
# features.denseblock4.denselayer3.layers.relu1
# features.denseblock4.denselayer3.layers.conv1
# features.denseblock4.denselayer3.layers.norm2
# features.denseblock4.denselayer3.layers.relu2
# features.denseblock4.denselayer3.layers.conv2
# features.denseblock4.denselayer4
# features.denseblock4.denselayer4.layers
# features.denseblock4.denselayer4.layers.norm1
# features.denseblock4.denselayer4.layers.relu1
# features.denseblock4.denselayer4.layers.conv1
# features.denseblock4.denselayer4.layers.norm2
# features.denseblock4.denselayer4.layers.relu2
# features.denseblock4.denselayer4.layers.conv2
# features.denseblock4.denselayer5
# features.denseblock4.denselayer5.layers
# features.denseblock4.denselayer5.layers.norm1
# features.denseblock4.denselayer5.layers.relu1
# features.denseblock4.denselayer5.layers.conv1
# features.denseblock4.denselayer5.layers.norm2
# features.denseblock4.denselayer5.layers.relu2
# features.denseblock4.denselayer5.layers.conv2
# features.denseblock4.denselayer6
# features.denseblock4.denselayer6.layers
# features.denseblock4.denselayer6.layers.norm1
# features.denseblock4.denselayer6.layers.relu1
# features.denseblock4.denselayer6.layers.conv1
# features.denseblock4.denselayer6.layers.norm2
# features.denseblock4.denselayer6.layers.relu2
# features.denseblock4.denselayer6.layers.conv2
# features.denseblock4.denselayer7
# features.denseblock4.denselayer7.layers
# features.denseblock4.denselayer7.layers.norm1
# features.denseblock4.denselayer7.layers.relu1
# features.denseblock4.denselayer7.layers.conv1
# features.denseblock4.denselayer7.layers.norm2
# features.denseblock4.denselayer7.layers.relu2
# features.denseblock4.denselayer7.layers.conv2
# features.denseblock4.denselayer8
# features.denseblock4.denselayer8.layers
# features.denseblock4.denselayer8.layers.norm1
# features.denseblock4.denselayer8.layers.relu1
# features.denseblock4.denselayer8.layers.conv1
# features.denseblock4.denselayer8.layers.norm2
# features.denseblock4.denselayer8.layers.relu2
# features.denseblock4.denselayer8.layers.conv2
# features.denseblock4.denselayer9
# features.denseblock4.denselayer9.layers
# features.denseblock4.denselayer9.layers.norm1
# features.denseblock4.denselayer9.layers.relu1
# features.denseblock4.denselayer9.layers.conv1
# features.denseblock4.denselayer9.layers.norm2
# features.denseblock4.denselayer9.layers.relu2
# features.denseblock4.denselayer9.layers.conv2
# features.denseblock4.denselayer10
# features.denseblock4.denselayer10.layers
# features.denseblock4.denselayer10.layers.norm1
# features.denseblock4.denselayer10.layers.relu1
# features.denseblock4.denselayer10.layers.conv1
# features.denseblock4.denselayer10.layers.norm2
# features.denseblock4.denselayer10.layers.relu2
# features.denseblock4.denselayer10.layers.conv2
# features.denseblock4.denselayer11
# features.denseblock4.denselayer11.layers
# features.denseblock4.denselayer11.layers.norm1
# features.denseblock4.denselayer11.layers.relu1
# features.denseblock4.denselayer11.layers.conv1
# features.denseblock4.denselayer11.layers.norm2
# features.denseblock4.denselayer11.layers.relu2
# features.denseblock4.denselayer11.layers.conv2
# features.denseblock4.denselayer12
# features.denseblock4.denselayer12.layers
# features.denseblock4.denselayer12.layers.norm1
# features.denseblock4.denselayer12.layers.relu1
# features.denseblock4.denselayer12.layers.conv1
# features.denseblock4.denselayer12.layers.norm2
# features.denseblock4.denselayer12.layers.relu2
# features.denseblock4.denselayer12.layers.conv2
# features.denseblock4.denselayer13
# features.denseblock4.denselayer13.layers
# features.denseblock4.denselayer13.layers.norm1
# features.denseblock4.denselayer13.layers.relu1
# features.denseblock4.denselayer13.layers.conv1
# features.denseblock4.denselayer13.layers.norm2
# features.denseblock4.denselayer13.layers.relu2
# features.denseblock4.denselayer13.layers.conv2
# features.denseblock4.denselayer14
# features.denseblock4.denselayer14.layers
# features.denseblock4.denselayer14.layers.norm1
# features.denseblock4.denselayer14.layers.relu1
# features.denseblock4.denselayer14.layers.conv1
# features.denseblock4.denselayer14.layers.norm2
# features.denseblock4.denselayer14.layers.relu2
# features.denseblock4.denselayer14.layers.conv2
# features.denseblock4.denselayer15
# features.denseblock4.denselayer15.layers
# features.denseblock4.denselayer15.layers.norm1
# features.denseblock4.denselayer15.layers.relu1
# features.denseblock4.denselayer15.layers.conv1
# features.denseblock4.denselayer15.layers.norm2
# features.denseblock4.denselayer15.layers.relu2
# features.denseblock4.denselayer15.layers.conv2
# features.denseblock4.denselayer16
# features.denseblock4.denselayer16.layers
# features.denseblock4.denselayer16.layers.norm1
# features.denseblock4.denselayer16.layers.relu1
# features.denseblock4.denselayer16.layers.conv1
# features.denseblock4.denselayer16.layers.norm2
# features.denseblock4.denselayer16.layers.relu2
# features.denseblock4.denselayer16.layers.conv2

# %%
from monai.visualize import GradCAM
from utils.data_visualization_functions import min_max_normalization
from utils.mlflow_functions import find_last_conv_layer
from utils.explainability_functions import process_and_save_batch_gradcam_and_Overlay
from utils.vit_explanation_functions import save_attention_overlays_side_by_side

model_name = cfg.get_model_name().lower()

if "vit" in model_name:
    print("Model identified as ViT-based; computing Attention Rollout...")
    attn_dir = OUTPUT_DIR / "attention_rollout"
    attn_dir.mkdir(parents=True, exist_ok=True)
    save_attention_overlays_side_by_side(
        data_loader=train_loader,
        model=model,
        output_directory=str(attn_dir),
        device=device,
        heatmap_alpha=0.6,
        input_order="gbr_graylast"
    )
    print(f"Attention rollouts saved to {attn_dir}")
else:
    print("Model identified as CNN-based; computing GradCAM...")
    target_layer, _ = find_last_conv_layer(model)
    if target_layer is None:
        raise RuntimeError("No convolutional layer found; GradCAM cannot be computed.")

    target_layer = "features.denseblock4.denselayer15.layers.conv2"
    gradcam = GradCAM(
        nn_module=model,
        target_layers=[target_layer],
        register_backward=True,
    )
    
    gradcam_dir = process_and_save_batch_gradcam_and_Overlay(
        model=model,
        test_loader=train_loader,
        gradcam_obj=gradcam,
        base_dir=OUTPUT_DIR,
        class_names=class_names,
        min_max_rescale_for_display=min_max_normalization,
        threshold=0.0,
        run_name=run.data.tags.get("mlflow.runName", RUN_ID),
        experiment_name=run.info.experiment_id,
    )
    print(f"GradCAM images saved to {gradcam_dir}")
# Out:
# Model identified as CNN-based; computing GradCAM...
# Processing batch 1, shape: torch.Size([32, 4, 512, 512])
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_0.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_1.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_2.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_3.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_4.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_5.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_6.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_7.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_8.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_9.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_10.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_11.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_12.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_13.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_14.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_15.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_16.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_17.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_18.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_19.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_20.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_21.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_22.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_23.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_24.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_25.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_26.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_27.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_28.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_29.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_30.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_0_img_31.png
# Processing batch 2, shape: torch.Size([32, 4, 512, 512])
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_0.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_1.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_2.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_3.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_4.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_5.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_6.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_7.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_8.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_9.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_10.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_11.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_12.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_13.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_14.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_15.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_16.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_17.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_18.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_19.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_20.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_21.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_22.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_23.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_24.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_25.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_26.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_27.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_28.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_29.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_30.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_1_img_31.png
# Processing batch 3, shape: torch.Size([32, 4, 512, 512])
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_0.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_1.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_2.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_3.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_4.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_5.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_6.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_7.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_8.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_9.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_10.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_11.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_12.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_13.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_14.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_15.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_16.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_17.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_18.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_19.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_20.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_21.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_22.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_23.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_24.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_25.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_26.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_27.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_28.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_29.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_30.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_2_img_31.png
# Processing batch 4, shape: torch.Size([32, 4, 512, 512])
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_0.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_1.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_2.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_3.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_4.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_5.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_6.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_7.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_8.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_9.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_10.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_11.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_12.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_13.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_14.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_15.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_16.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_17.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_18.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_19.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_20.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_21.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_22.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_23.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_24.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_25.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_26.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_27.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_28.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_29.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_30.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_3_img_31.png
# Processing batch 5, shape: torch.Size([32, 4, 512, 512])
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_0.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_1.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_2.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_3.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_4.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_5.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_6.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_7.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_8.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_9.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_10.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_11.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_12.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_13.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_14.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_15.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_16.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_17.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_18.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_19.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_20.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_21.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_22.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_23.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_24.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_25.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_26.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_27.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_28.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_29.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_30.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_4_img_31.png
# Processing batch 6, shape: torch.Size([4, 4, 512, 512])
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_5_img_0.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_5_img_1.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_5_img_2.png
# Saved GRADCAM overlay with DAPI-like channel to: /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52/batch_5_img_3.png
# GradCAM images saved to /home/zano/Documents/TESI/FOLDER_CINECA/notebooks/images/2c2e7113057d45859a0c881f3861f2e5_explanations/gradcam_outputs/Densenet121_oversamp_monai_11-02_at:15-43-52
